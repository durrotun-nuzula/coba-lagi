# %%
import pandas as pd
import numpy as np

# %%
from urllib.request import urlretrieve
url ='http://data.jakarta.go.id/dataset/99e10fc1-9669-4b49-bf71-09646567bb2e/resource/874876e1-ee4d-4c25-8aa2-f027a99ec673/download/DATA-KUNJUNGAN-WISATAWAN-MANCANEGARA-ver.xlsx'
datajakarta= urlretrieve(url,'DATA-KUNJUNGAN-WISATAWAN-MANCANEGARA-ver.xlsx')
datajakarta
# Out:
# ('DATA-KUNJUNGAN-WISATAWAN-MANCANEGARA-ver.xlsx',
#  <http.client.HTTPMessage at 0x13a8dd6ea90>)

# %%
#url1='http://data.jakarta.go.id/dataset/9b122715-9555-4ede-a473-1b5dff7d446d/resource/bc4773e3-2d2b-4cea-82e9-9ee2cdafd1c1/download/DATA-INDUSTRI-PARIWISATA-DKI-JAKARTA-TAHUN-2014-ver-xlsx.csv'
datajakarta1=urlretrieve('http://data.jakarta.go.id/dataset/9b122715-9555-4ede-a473-1b5dff7d446d/resource/bc4773e3-2d2b-4cea-82e9-9ee2cdafd1c1/download/DATA-INDUSTRI-PARIWISATA-DKI-JAKARTA-TAHUN-2014-ver-xlsx.csv')
datajakarta1
# Out:
# ('C:\\Users\\Dell\\AppData\\Local\\Temp\\tmp258f62xs',
#  <http.client.HTTPMessage at 0x13a8dd6ef98>)

# %%
datajakarta2,headers=urllib.request.urlretrieve('http://data.jakarta.go.id/dataset/c35df0d0-51cc-40af-808e-3aba14096ac0/resource/4389d767-eaf4-4b20-9c63-b6cbcb745511/download/processed-data-taman-rekreasi-jakarta.csv')
htlm=open(datajakarta2)
htlm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-69b95a0e3759> in <module>()
# ----> 1 datajakarta2,headers=urllib.request.urlretrieve('http://data.jakarta.go.id/dataset/c35df0d0-51cc-40af-808e-3aba14096ac0/resource/4389d767-eaf4-4b20-9c63-b6cbcb745511/download/processed-data-taman-rekreasi-jakarta.csv')
#       2 htlm=open(datajakarta2)
#       3 htlm
#
# NameError: name 'urllib' is not defined

# %%
import urllib
datajakarta1=urllib.request.urlopen('http://data.jakarta.go.id/dataset/9b122715-9555-4ede-a473-1b5dff7d446d/resource/bc4773e3-2d2b-4cea-82e9-9ee2cdafd1c1/download/DATA-INDUSTRI-PARIWISATA-DKI-JAKARTA-TAHUN-2014-ver-xlsx.csv')
data1=pd.read_csv(datajakarta1)
data1
# Out:
#             wilayah  akomodasi_jumlah_usaha  akomodasi_kamar  \
# 0     JAKARTA PUSAT                   205.0          29571.0
# 1     JAKARTA UTARA                    59.0           7420.0
# 2     JAKARTA BARAT                   104.0          11476.0
# 3     JAKARTA TIMUR                    29.0           3010.0
# 4  JAKARTA SELATAN                    119.0          16515.0
#
#    hiburan_dan_rekreasi  penyedia_jasa_makan_dan_minum  biro_perjalanan
# 0                 224.0                         1259.0            402.0
# 1                 285.0                          937.0            134.0
# 2                 300.0                          742.0            180.0
# 3                  88.0                          262.0            334.0
# 4                 390.0                         2204.0            698.0

# %%
datajakarta2=urllib.request.urlopen('http://data.jakarta.go.id/dataset/c35df0d0-51cc-40af-808e-3aba14096ac0/resource/4389d767-eaf4-4b20-9c63-b6cbcb745511/download/processed-data-taman-rekreasi-jakarta.csv')
data2=pd.read_csv(datajakarta2)
data2
# Out:
#     NO   KODIFIKASI                         NAMA          LOKASI  \
# 0  1.0   33000001.0  Taman Kebun Bibit Srengseng               -
# 1  2.0   33000002.0   Taman Kebun Bibit Ciganjur               -
# 2  3.0  854030001.0              Bumi Perkemahan  Jl. Harsono RM
# 3  4.0   33000003.0      Taman kebun Bibit Tebet               -
# 4  NaN          NaN                          NaN             NaN
#
#          KOTAMADYA     KECAMATAN    KELURAHAN       LUAS           JENIS
# 0    Jakarta Barat   Kebon Jeruk    Srengseng  69,967.00  Taman Rekreasi
# 1  Jakarta Selatan     Jagakarsa     Ciganjur  48,670.00  Taman Rekreasi
# 2  Jakarta Selatan  Pasar Minggu      Ragunan  74,717.00  Taman Rekreasi
# 3  Jakarta Selatan         Tebet  Tebet Barat  48,166.00  Taman Rekreasi
# 4              NaN           NaN          NaN        NaN             NaN

# %%
datajakarta3=urllib.request.urlopen('http://data.jakarta.go.id/dataset/99e10fc1-9669-4b49-bf71-09646567bb2e/resource/874876e1-ee4d-4c25-8aa2-f027a99ec673/download/DATA-KUNJUNGAN-WISATAWAN-MANCANEGARA-ver.xlsx')
data3=pd.read_excel(datajakarta3)
data3
# Out:
#                    tahun     jumlah  pertumbuhan(%)
# 0                   2010  1892866.0             NaN
# 1                   2011  2003944.0          0.0587
# 2                   2012  2125513.0          0.0607
# 3                   2013  2313742.0          0.0886
# 4                   2014  2319295.0          0.0024
# 5  Januari-Februari 2015   352649.0             NaN

# %%
datajakarta4=urllib.request.urlopen('http://data.jakarta.go.id/dataset/4a71ecc6-7663-45cd-89c5-aa06adce91f0/resource/b5df7a67-14d6-4cbd-a4b4-be86ec70b813/download/Wisnus-ke-Destinasi-Wisata-di-DKI-Jakarta-Tahun-2012-edited.csv')
data2012=pd.read_csv(datajakarta4)
jkt2012=data2012[['nama_destinasi_wisata','nama_kabupaten_kota','jumlah']]

# %%
datajakarta5=urllib.request.urlopen('http://data.jakarta.go.id/dataset/4a71ecc6-7663-45cd-89c5-aa06adce91f0/resource/8a6eb1e8-3e50-4c6d-88c6-ec843af7b69f/download/Wisnus-ke-Destinasi-Wisata-di-DKI-Jakarta-Tahun-2013-edited.csv')
data2013=pd.read_csv(datajakarta5)
jkt2013=data2013[['nama_destinasi_wisata','nama_kabupaten_kota','jumlah']]

# %%
datajakarta6=urllib.request.urlopen('http://data.jakarta.go.id/dataset/4a71ecc6-7663-45cd-89c5-aa06adce91f0/resource/8f96ff5c-e03c-4425-be6c-f51103ffcf96/download/Wisnus-ke-Destinasi-Wisata-di-DKI-Jakarta-Tahun-2014-edited.csv')
data2014=pd.read_csv(datajakarta6)
jkt2014=data2014[['nama_destinasi_wisata','nama_kabupaten_kota','jumlah']]

# %%
datajakarta7=urllib.request.urlopen('http://data.jakarta.go.id/dataset/4a71ecc6-7663-45cd-89c5-aa06adce91f0/resource/bf0be37d-ebeb-4ce0-b772-03a9044317d2/download/Wisnus-ke-Destinasi-Wisata-di-DKI-Jakarta-Tahun-2015-edited.csv')
data2015=pd.read_csv(datajakarta7)
jkt2015=data2015[['nama_destinasi_wisata','nama_kabupaten_kota','jumlah']]

# %%
datajakarta8=urllib.request.urlopen('http://data.jakarta.go.id/dataset/4a71ecc6-7663-45cd-89c5-aa06adce91f0/resource/a05961eb-7bc6-4a7b-a29e-98d4758c9294/download/Wisnus-ke-Destinasi-Wisata-di-DKI-Jakarta-Tahun-2016-edited.csv')
data2016=pd.read_csv(datajakarta8)
jkt2016=data2016[['nama_destinasi_wisata','nama_kabupaten_kota','jumlah']]

# %%
visitorTIJA={"year":[2017, 2016, 2015, 2014, 2013],"visitor":[18713717, 18007919, 17820962, 16748879, 15948839]}

# %%
visitor_df=pd.DataFrame(visitorTIJA)
visitor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-97383136b2df> in <module>()
#       1 visitor_df=pd.DataFrame(visitorTIJA)
# ----> 2 visitor
#
# NameError: name 'visitor' is not defined

# %%
wisataJKT=[data2012, data2013, data2014, data2015, data2016]

# %%
data2012.append(data2013)
# Out:
#      tahun nama_provinsi         nama_destinasi_wisata nama_kabupaten_kota  \
# 0   2012.0   DKI Jakarta                   TIJA Ancol*       Jakarta Utara
# 1   2012.0   DKI Jakarta   Taman Mini Indonesia Indah*       Jakarta Timur
# 2   2012.0   DKI Jakarta       T. Marga Satwa Ragunan*     Jakarta Selatan
# 3   2012.0   DKI Jakarta              Monumen Nasional       Jakarta Pusat
# 4   2012.0   DKI Jakarta               Museum Nasional       Jakarta Pusat
# 5   2012.0   DKI Jakarta         Museum Satria Mandala     Jakarta Selatan
# 6   2012.0   DKI Jakarta        Museum Sejarah Jakarta       Jakarta Barat
# 7   2012.0   DKI Jakarta                Museum Tekstil       Jakarta Barat
# 8   2012.0   DKI Jakarta                 Museum Bahari       Jakarta Utara
# 9   2012.0   DKI Jakarta      M. Seni Rupa dan Keramik       Jakarta Barat
# 10  2012.0   DKI Jakarta                 Museum Wayang       Jakarta Barat
# ...

# %%
attractionJKT=data2012["nama_destinasi_wisata"]
wisata2012=data2012["jumlah"]
wisata2013=data2013["jumlah"]
wisata2014=data2014["jumlah"]
wisata2015=data2015["jumlah"]
wisata2016=data2016["jumlah"]
wisataJKT=pd.concat([attractionJKT,wisata2012,wisata2013,wisata2014,wisata2015,wisata2016], keys=["attraction name", 2012, 2013, 2014, 2015, 2016],axis='columns')
wisataJKT
# Out:
#                  attraction name        2012        2013        2014  \
# 0                    TIJA Ancol*  15848956.0  15948829.0  16085604.0
# 1    Taman Mini Indonesia Indah*   4726273.0   4483847.0   4587735.0
# 2        T. Marga Satwa Ragunan*   4283895.0   3681968.0   4100249.0
# 3               Monumen Nasional   1418469.0   1115360.0   1135944.0
# 4                Museum Nasional    148118.0    152691.0    245848.0
# 5          Museum Satria Mandala     44353.0     42456.0     38756.0
# 6         Museum Sejarah Jakarta    396253.0    337262.0    190044.0
# 7                 Museum Tekstil     59727.0     38236.0     50612.0
# 8                  Museum Bahari     20097.0     17602.0     18610.0
# 9       M. Seni Rupa dan Keramik     49308.0     75214.0    116083.0
# 10                 Museum Wayang    187386.0    188910.0    318560.0
# 11              Museum Joang '45     20707.0     14571.0     19398.0
# 12      Taman Arkeologi P.Onrust     13593.0     20929.0     37106.0
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
help(sns.lmplot)
# Out:
# Help on function lmplot in module seaborn.linearmodels:
#
# lmplot(x, y, data, hue=None, col=None, row=None, palette=None, col_wrap=None, size=5, aspect=1, markers='o', sharex=True, sharey=True, hue_order=None, col_order=None, row_order=None, legend=True, legend_out=True, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=False, x_jitter=None, y_jitter=None, scatter_kws=None, line_kws=None)
#     Plot data and regression model fits across a FacetGrid.
#
#     This function combines :func:`regplot` and :class:`FacetGrid`. It is
#     intended as a convenient interface to fit regression models across
#     conditional subsets of a dataset.
#
#     When thinking about how to assign variables to different facets, a general
#     rule is that it makes sense to use ``hue`` for the most important
# ...

# %%
wisataJKT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 6 columns):
# attraction name    17 non-null object
# 2012               14 non-null float64
# 2013               14 non-null float64
# 2014               14 non-null float64
# 2015               14 non-null float64
# 2016               17 non-null float64
# dtypes: float64(5), object(1)
# memory usage: 944.0+ bytes

# %%
wisataJKT.describe()
# Out:
#                2012          2013          2014          2015          2016
# count  1.400000e+01  1.400000e+01  1.400000e+01  1.400000e+01  1.700000e+01
# mean   1.946364e+06  1.868319e+06  1.928179e+06  2.179499e+06  1.921998e+06
# std    4.306331e+06  4.301936e+06  4.350652e+06  4.571328e+06  4.417628e+06
# min    1.359300e+04  1.457100e+04  1.861000e+04  8.909000e+03  8.596000e+03
# 25%    3.505525e+04  3.832500e+04  4.155700e+04  5.205800e+04  3.971600e+04
# 50%    1.039225e+05  1.139525e+05  1.530635e+05  2.006195e+05  2.891960e+05
# 75%    1.162915e+06  9.208355e+05  9.315980e+05  1.271260e+06  7.272180e+05
# max    1.584896e+07  1.594883e+07  1.608560e+07  1.666152e+07  1.785028e+07

# %%
df=pd.melt(frame=wisataJKT,id_vars='attraction name',var_name='year',value_name='visitor')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_coba=df(index='attraction name', columns='year',value='visitor')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-965f95d04ea9> in <module>()
# ----> 1 df_coba=df(index='attraction name', columns='year',value='visitor')
#
# TypeError: 'DataFrame' object is not callable

# %%
 jkt2016.sort_values(by=['jumlah'], ascending=False)
# Out:
#            nama_destinasi_wisata nama_kabupaten_kota    jumlah
# 0                    TIJA Ancol*       Jakarta Utara  17850284
# 2        T. Marga Satwa Ragunan*     Jakarta Selatan   5177877
# 1    Taman Mini Indonesia Indah*       Jakarta Timur   4977704
# 3               Monumen Nasional       Jakarta Pusat   1863699
# 6         Museum Sejarah Jakarta       Jakarta Barat    727218
# 14             Kepulauan Seribu        Jakarta Utara    681355
# 4                Museum Nasional       Jakarta Pusat    349461
# 15             PBB Setu Babakan      Jakarta Selatan    338681
# 10                 Museum Wayang       Jakarta Barat    289196
# 9       M. Seni Rupa dan Keramik       Jakarta Barat    163775
# 8                  Museum Bahari       Jakarta Utara     72143
# 7                 Museum Tekstil       Jakarta Barat     44357
# 13             Pel. Sunda Kelapa       Jakarta Utara     39716
# 12      Taman Arkeologi P.Onrust       Jakarta Utara     39514
# ...

# %%
data_loket_dufan = pd.read_excel('query_result_2018-10-25T03_15_45.093Z.xlsx', index_col=0, parse_dates=True)
data_loket_dufan
# Out:
#               ticket_sold
# invoice_date
# 2018-01-04              2
# 2018-01-05              4
# 2018-01-07              2
# 2018-03-02              1
# 2018-03-05              5
# 2018-03-09              6
# 2018-03-10              9
# 2018-03-11             10
# 2018-03-14              1
# 2018-03-22              2
# 2018-03-23              2
# 2018-03-24              4
# 2018-03-29             11
# 2018-03-30              5
# 2018-03-31              4
# 2018-04-03              3
# 2018-04-04             14
# 2018-04-05             10
# 2018-04-06             25
# 2018-04-07              4
# 2018-04-08             15
# 2018-04-11             11
# 2018-04-12             12
# 2018-04-13              9
# 2018-04-14              3
# 2018-04-15              6
# 2018-04-16              2
# 2018-04-17              4
# 2018-04-18              4
# 2018-04-21              2
# ...                   ...
# 2018-05-06              2
# 2018-05-08              2
# 2018-05-10              7
# ...

# %%
# %matplotlib inline
plt.style.use('seaborn')
plt.plot(data_loket_dufan['ticket_sold'])
